# %% [markdown]
# # Components of Custom Data Loader in PyTorch

# %% [markdown]
# From previous tutorial (linear-regression.ipynb)
#
# The dataset has been loaded from kagglehub
#
# What is Data Loader exactly ?
#
# Previously from kaggle the insurance.csv has been loaded on cache, and it has been used in the custom NN...
# Pre processing and reformulating the data form (cathegorical data to numerical form)
#
# Dataset has been scaled (normalized) based on data properties (mean, std dev)

# %% [markdown]
# When Training the model, with model.train() we are passing the whole tensor in a single iteration thousands of samples all at once !
#
# 1 epoch: all the row data ! If e.g.
#
# x_train_tensor = 1000000 rows (dataset)
#
# In a single iteratiion all this is sent on memory ! e.g. 10GB of GPU VRAM can be allocated, causing Out Of Memory OOM
#
#
# With slow CPU usage, but enogh RAM to store the data:
#
# gradient descent and optim occurs only after all rows are computed, single epoch of gradient update after 1M iterations...
#
#
# If we are teaching human: A book of 1k pages, student learn 1k and after that: I don't understand...Maybe issue on the go! Only when all completed you say if you undretsand. We want a feedback during learning, e.g. every 10 pages -> feedback allow better learning and faster update
#
#
# 1k pages with 10 pages per step, 100 iterations per epoch.
#
# 100 feedback (iterations) on 1000 data is 1 epoch.
#
# If overall 100 epochs, 100*100 = 10000 iterations . Update weights more frequently and not running out of memory, passing chanks of data using data loader

# %%
# You load a chunk of data with a custom data loader !
# It is possible by creating it and using for training in batches to optimize data utilization and updates 

# Necessary components: 
# 1. Dataset: torch.utils.data.DataSet
# rsponsible for loading and processing data, for example from a cvs there are all the method of preprocessing 
# In Dataset you define how data is stored, acessed, transformed, how to retrieve samples
# 
# 2. DataLoader: torch.utils.data.DataLoader
# DataLoader is built in in pytorch, after defining the custom dataset, 
# DataLoader help to wraps the dataset in iterable object that load data in batches (specify amount of rows)
# Handles batching and parallel processing with multiple workers

# Create custom Dataset in pytorch: require the init() and so on...
# init() initialize the dataset, loads data, apply transformation if needed (preprocessing)

# len() : to return the length of the dataset as total number of rows (samples) in the dataset 
# Required because pytorch read it internally when loading in pytorch from there  
# (Initial index to final index knowing the len..) DataLoader will wrap the Dataset
# DataLoader will know the len using this method 

# getitem(): defines how to retrieve a single data sample when an index is provided
# used by DataLoader to get the actual data from that class (load in batches if required)

import kagglehub

# Download latest version of the dataset with kaggle
path = kagglehub.dataset_download("mirichoi0218/insurance")

print(f"Path of dataset files : {path}") # Stored in the cache


import pandas as pd
import os

df = pd.read_csv(os.path.join(path, 'insurance.csv'))


# I want to implement the code for loading in batches 
# The loader should be used for the training set, not on the validation level
# Out:
# Path of dataset files : /home/ale/.cache/kagglehub/datasets/mirichoi0218/insurance/versions/1

# %%
import torch 
from torch.utils.data import Dataset, DataLoader

# Define components for data preprocessing for model training 
import torch
import torch.nn as nn
import torch.optim as optim

# Using sklearn for data pre-processing
from sklearn.preprocessing import LabelEncoder, StandardScaler 
# we need LabelEncoder to transform the dataset
from sklearn.model_selection import train_test_split # help to divide the dataset

# Split dataset 
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42) # 80% as train, 20% as test

label_encoder = {}

for col in ['sex', 'smoker', 'region']:
    le = LabelEncoder()
    train_df[col] = le.fit_transform(train_df[col])
    test_df[col] = le.transform(test_df[col]) # Transform test set 
    label_encoder[col] = le

print(label_encoder)

# create features and target columns 
# X and Y

X_train = train_df.drop(columns=['charges']) # all except charges
y_train = train_df['charges'] # take just charges 

X_test = test_df.drop(columns=['charges']) # all except charges
y_test = test_df['charges'] # take just charges 

scaler = StandardScaler()

# Normalize on all features (NOT TARGET)
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32).view(-1, 1) # Flatten the output
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.values, dtype=torch.float32).view(-1, 1)


# NN model 

class SimpleNNRegressionModel(nn.Module):
    def __init__(self, input_dim):

        super(SimpleNNRegressionModel, self).__init__()

        # Very simple model, Sequential is enough
        self.network = nn.Sequential(
            nn.Linear(input_dim, 64), # 64 neurons of first hidden layer
            nn.ReLU(),
            nn.Linear(64, 128), # map to 128 neurons on next hidden layer 
            nn.ReLU(),
            nn.Linear(128, 1) # here the final layer of 128 is mapped to regrssion output of dimension 1
        )

    def forward(self, x):
        return self.network(x) # produce the output forward passing x on the network
    
# Initialize model from the custom NN 
input_dim = X_train_tensor.shape[1] # we are interested on feature lenght of each data
model = SimpleNNRegressionModel(input_dim=input_dim)


# Initialize other nn components, Loss and Optimizer

criterion = nn.MSELoss() # In regression MSE loss is enough
optimizer = optim.Adam(model.parameters(), lr=0.01) # Adam optimizer
# Out:
# {'sex': LabelEncoder(), 'smoker': LabelEncoder(), 'region': LabelEncoder()}

# %%
# PyTorch custom dataset handling init, len, getitem
# in principle the csv to numpy conversion and preprocessing happen on the init method 

class InsuranceDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y
        # It is possible to start from reading the data giving the path of the csv
        # Here pre processing is already been done

    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        # How to retrieve a SINGLE DATA SAMPLE
        # After label encoding, we start from the np array
        features =  torch.tensor(self.X[idx], dtype=torch.float32) # return a row of the data
        target =  torch.tensor(self.y.values[idx], dtype=torch.float32) # return a row of the data

        return features, target

# %%
# DataLoader will wrap Insurance 
dataset = InsuranceDataset(X_train, y_train)

# %%
# once created dataset, DataLoader is used to wrap it!
dataloader = DataLoader(dataset, batch_size=32, shuffle=True, num_workers=2)
# shuffle tell you that data will be evrytime in random order, with 32 data per retrieval

# now dataloader is an iterable over the dataset

# %%
for batch_idx, (features, targets) in enumerate(dataloader):
    print(f"Batch {batch_idx + 1}")
    print(f"Features :  {features.shape}")
    print(f"Targets:  {targets.shape}")

# batch size refer to the way of exploring the dataset in each epoch, 
# defined the batch size the number of iterations are affected by data_len/batch_size
# The last iterations will do the final data
# Out:
# Batch 1
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 2
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 3
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 4
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 5
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 6
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 7
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 8
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 9
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 10
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 11
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 12
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 13
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 14
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 15
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 16
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 17
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 18
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 19
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 20
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 21
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 22
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 23
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 24
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 25
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 26
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 27
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 28
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 29
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 30
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 31
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 32
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 33
# Features :  torch.Size([32, 6])
# Targets:  torch.Size([32])
# Batch 34
# Features :  torch.Size([14, 6])
# Targets:  torch.Size([14])

# %%
# Model training in batches 
# Create training loop 
epochs = 1000
for epoch in range(epochs):
    model.train()           # train method tell pytorch to store history of model training
    # while to test the model, model.eval() is to use in feed forward

    # I want to perform the below code for all batches 
    for batch_idx, (batch_X, batch_y) in enumerate(dataloader):

        print(f"Current Batch: {batch_idx + 1}")

        optimizer.zero_grad()   # clear gradients

        predictions = model(batch_X)
        loss = criterion(predictions, batch_y)
        loss.backward() #  compute gradients

        optimizer.step() # update weights using gradients computed 
        print(f"Epoch: [{epoch+1}/{epochs}], Batch {batch_idx + 1}, Loss : {loss.item():.4f}")

    if (epoch + 1) % 100 == 0:
        print(f"Epoch [{epoch+1}/{epochs}], Loss : {loss.item():.4f}")
# Out:
# Current Batch: 1
# Epoch: [1/1000], Batch 1, Loss : 67250392.0000
# Current Batch: 2
# Epoch: [1/1000], Batch 2, Loss : 167153376.0000
# Current Batch: 3
# Epoch: [1/1000], Batch 3, Loss : 107152384.0000
# Current Batch: 4
# Epoch: [1/1000], Batch 4, Loss : 128527216.0000
# Current Batch: 5
# Epoch: [1/1000], Batch 5, Loss : 103536176.0000
# Current Batch: 6
# Epoch: [1/1000], Batch 6, Loss : 202315024.0000
# Current Batch: 7
# Epoch: [1/1000], Batch 7, Loss : 234889232.0000
# Current Batch: 8
# /home/ale/anaconda3/envs/pytorch_gpu12_8/lib/python3.11/site-packages/torch/nn/modules/loss.py:634: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch: [1/1000], Batch 8, Loss : 149055008.0000
# Current Batch: 9
# Epoch: [1/1000], Batch 9, Loss : 134792432.0000
# Current Batch: 10
# Epoch: [1/1000], Batch 10, Loss : 93969760.0000
# Current Batch: 11
# Epoch: [1/1000], Batch 11, Loss : 124896464.0000
# Current Batch: 12
# Epoch: [1/1000], Batch 12, Loss : 66941864.0000
# Current Batch: 13
# Epoch: [1/1000], Batch 13, Loss : 76407256.0000
# Current Batch: 14
# Epoch: [1/1000], Batch 14, Loss : 141604928.0000
# Current Batch: 15
# Epoch: [1/1000], Batch 15, Loss : 66960080.0000
# Current Batch: 16
# Epoch: [1/1000], Batch 16, Loss : 245238880.0000
# Current Batch: 17
# Epoch: [1/1000], Batch 17, Loss : 86791520.0000
# Current Batch: 18
# Epoch: [1/1000], Batch 18, Loss : 151494192.0000
# Current Batch: 19
# Epoch: [1/1000], Batch 19, Loss : 215265248.0000
# Current Batch: 20
# Epoch: [1/1000], Batch 20, Loss : 156591232.0000
# Current Batch: 21
# Epoch: [1/1000], Batch 21, Loss : 203237184.0000
# Current Batch: 22
# Epoch: [1/1000], Batch 22, Loss : 192863328.0000
# Current Batch: 23
# Epoch: [1/1000], Batch 23, Loss : 156167936.0000
# Current Batch: 24
# Epoch: [1/1000], Batch 24, Loss : 145664672.0000
# Current Batch: 25
# Epoch: [1/1000], Batch 25, Loss : 143444176.0000
# Current Batch: 26
# Epoch: [1/1000], Batch 26, Loss : 189213536.0000
# Current Batch: 27
# Epoch: [1/1000], Batch 27, Loss : 157102496.0000
# Current Batch: 28
# Epoch: [1/1000], Batch 28, Loss : 229628128.0000
# Current Batch: 29
# Epoch: [1/1000], Batch 29, Loss : 115319344.0000
# Current Batch: 30
# Epoch: [1/1000], Batch 30, Loss : 225668048.0000
# Current Batch: 31
# Epoch: [1/1000], Batch 31, Loss : 80502184.0000
# Current Batch: 32
# Epoch: [1/1000], Batch 32, Loss : 88105224.0000
# Current Batch: 33
# Epoch: [1/1000], Batch 33, Loss : 159390352.0000
# Current Batch: 34
# Epoch: [1/1000], Batch 34, Loss : 45485436.0000
# /home/ale/anaconda3/envs/pytorch_gpu12_8/lib/python3.11/site-packages/torch/nn/modules/loss.py:634: UserWarning: Using a target size (torch.Size([14])) that is different to the input size (torch.Size([14, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Current Batch: 1
# Epoch: [2/1000], Batch 1, Loss : 115349320.0000
# Current Batch: 2
# Epoch: [2/1000], Batch 2, Loss : 73723200.0000
# Current Batch: 3
# Epoch: [2/1000], Batch 3, Loss : 195563344.0000
# Current Batch: 4
# Epoch: [2/1000], Batch 4, Loss : 207397136.0000
# Current Batch: 5
# Epoch: [2/1000], Batch 5, Loss : 195648352.0000
# Current Batch: 6
# Epoch: [2/1000], Batch 6, Loss : 164962272.0000
# Current Batch: 7
# Epoch: [2/1000], Batch 7, Loss : 116069072.0000
# Current Batch: 8
# Epoch: [2/1000], Batch 8, Loss : 118908664.0000
# Current Batch: 9
# Epoch: [2/1000], Batch 9, Loss : 89995408.0000
# Current Batch: 10
# Epoch: [2/1000], Batch 10, Loss : 151873360.0000
# Current Batch: 11
# Epoch: [2/1000], Batch 11, Loss : 133877880.0000
# Current Batch: 12
# Epoch: [2/1000], Batch 12, Loss : 91721664.0000
# Current Batch: 13
# Epoch: [2/1000], Batch 13, Loss : 76530848.0000
# Current Batch: 14
# Epoch: [2/1000], Batch 14, Loss : 134786752.0000
# Current Batch: 15
# Epoch: [2/1000], Batch 15, Loss : 293419008.0000
# Current Batch: 16
# Epoch: [2/1000], Batch 16, Loss : 98946904.0000
# Current Batch: 17
# Epoch: [2/1000], Batch 17, Loss : 160739744.0000
# Current Batch: 18
# Epoch: [2/1000], Batch 18, Loss : 140068080.0000
# Current Batch: 19
# Epoch: [2/1000], Batch 19, Loss : 192491664.0000
# Current Batch: 20
# Epoch: [2/1000], Batch 20, Loss : 100382768.0000
# Current Batch: 21
# Epoch: [2/1000], Batch 21, Loss : 126162488.0000
# Current Batch: 22
# Epoch: [2/1000], Batch 22, Loss : 113018984.0000
# Current Batch: 23
# Epoch: [2/1000], Batch 23, Loss : 98101792.0000
# Current Batch: 24
# Epoch: [2/1000], Batch 24, Loss : 208820992.0000
# Current Batch: 25
# Epoch: [2/1000], Batch 25, Loss : 263424208.0000
# Current Batch: 26
# Epoch: [2/1000], Batch 26, Loss : 66224068.0000
# Current Batch: 27
# Epoch: [2/1000], Batch 27, Loss : 170587648.0000
# Current Batch: 28
# Epoch: [2/1000], Batch 28, Loss : 178421712.0000
# Current Batch: 29
# Epoch: [2/1000], Batch 29, Loss : 142946272.0000
# Current Batch: 30
# Epoch: [2/1000], Batch 30, Loss : 137619712.0000
# Current Batch: 31
# Epoch: [2/1000], Batch 31, Loss : 83621560.0000
# Current Batch: 32
# Epoch: [2/1000], Batch 32, Loss : 171578480.0000
# Current Batch: 33
# Epoch: [2/1000], Batch 33, Loss : 166374912.0000
# Current Batch: 34
# Epoch: [2/1000], Batch 34, Loss : 113811624.0000
# Current Batch: 1
# Epoch: [3/1000], Batch 1, Loss : 217877600.0000
# Current Batch: 2
# Epoch: [3/1000], Batch 2, Loss : 176459408.0000
# Current Batch: 3
# Epoch: [3/1000], Batch 3, Loss : 152795808.0000
# Current Batch: 4
# Epoch: [3/1000], Batch 4, Loss : 188999088.0000
# Current Batch: 5
# Epoch: [3/1000], Batch 5, Loss : 90137016.0000
# Current Batch: 6
# Epoch: [3/1000], Batch 6, Loss : 187749920.0000
# Current Batch: 7
# Epoch: [3/1000], Batch 7, Loss : 104331360.0000
# Current Batch: 8
# Epoch: [3/1000], Batch 8, Loss : 232716928.0000
# Current Batch: 9
# Epoch: [3/1000], Batch 9, Loss : 174339216.0000
# Current Batch: 10
# Epoch: [3/1000], Batch 10, Loss : 125275600.0000
# Current Batch: 11
# Epoch: [3/1000], Batch 11, Loss : 63951872.0000
# Current Batch: 12
# Epoch: [3/1000], Batch 12, Loss : 85834080.0000
# Current Batch: 13
# Epoch: [3/1000], Batch 13, Loss : 135382288.0000
# Current Batch: 14
# Epoch: [3/1000], Batch 14, Loss : 131265744.0000
# Current Batch: 15
# Epoch: [3/1000], Batch 15, Loss : 239755424.0000
# Current Batch: 16
# Epoch: [3/1000], Batch 16, Loss : 158757024.0000
# Current Batch: 17
# Epoch: [3/1000], Batch 17, Loss : 139889216.0000
# Current Batch: 18
# Epoch: [3/1000], Batch 18, Loss : 187834384.0000
# Current Batch: 19
# Epoch: [3/1000], Batch 19, Loss : 66915112.0000
# Current Batch: 20
# Epoch: [3/1000], Batch 20, Loss : 106901512.0000
# Current Batch: 21
# Epoch: [3/1000], Batch 21, Loss : 89483288.0000
# Current Batch: 22
# Epoch: [3/1000], Batch 22, Loss : 203938992.0000
# Current Batch: 23
# Epoch: [3/1000], Batch 23, Loss : 117911560.0000
# Current Batch: 24
# Epoch: [3/1000], Batch 24, Loss : 140610368.0000
# Current Batch: 25
# Epoch: [3/1000], Batch 25, Loss : 101489488.0000
# Current Batch: 26
# Epoch: [3/1000], Batch 26, Loss : 138745120.0000
# Current Batch: 27
# Epoch: [3/1000], Batch 27, Loss : 161841392.0000
# Current Batch: 28
# Epoch: [3/1000], Batch 28, Loss : 183645040.0000
# Current Batch: 29
# Epoch: [3/1000], Batch 29, Loss : 140718688.0000
# Current Batch: 30
# Epoch: [3/1000], Batch 30, Loss : 90626968.0000
# Current Batch: 31
# Epoch: [3/1000], Batch 31, Loss : 122275312.0000
# Current Batch: 32
# Epoch: [3/1000], Batch 32, Loss : 100106864.0000
# Current Batch: 33
# Epoch: [3/1000], Batch 33, Loss : 231687696.0000
# Current Batch: 34
# Epoch: [3/1000], Batch 34, Loss : 122531248.0000
# Current Batch: 1
# Epoch: [4/1000], Batch 1, Loss : 47835552.0000
# Current Batch: 2
# Epoch: [4/1000], Batch 2, Loss : 90534256.0000
# Current Batch: 3
# Epoch: [4/1000], Batch 3, Loss : 127764400.0000
# Current Batch: 4
# Epoch: [4/1000], Batch 4, Loss : 134264560.0000
# Current Batch: 5
# Epoch: [4/1000], Batch 5, Loss : 161904480.0000
# Current Batch: 6
# Epoch: [4/1000], Batch 6, Loss : 210536752.0000
# Current Batch: 7
# Epoch: [4/1000], Batch 7, Loss : 246142832.0000
# Current Batch: 8
# Epoch: [4/1000], Batch 8, Loss : 100739760.0000
# Current Batch: 9
# Epoch: [4/1000], Batch 9, Loss : 118970800.0000
# Current Batch: 10
# Epoch: [4/1000], Batch 10, Loss : 229762880.0000
# Current Batch: 11
# Epoch: [4/1000], Batch 11, Loss : 94131848.0000
# Current Batch: 12
# Epoch: [4/1000], Batch 12, Loss : 162012880.0000
# Current Batch: 13
# Epoch: [4/1000], Batch 13, Loss : 161570816.0000
# Current Batch: 14
# Epoch: [4/1000], Batch 14, Loss : 69516672.0000
# Current Batch: 15
# Epoch: [4/1000], Batch 15, Loss : 114133616.0000
# Current Batch: 16
# Epoch: [4/1000], Batch 16, Loss : 123668512.0000
# Current Batch: 17
# Epoch: [4/1000], Batch 17, Loss : 205322224.0000
# Current Batch: 18
# Epoch: [4/1000], Batch 18, Loss : 119088616.0000
# Current Batch: 19
# Epoch: [4/1000], Batch 19, Loss : 173401856.0000
# Current Batch: 20
# Epoch: [4/1000], Batch 20, Loss : 150562256.0000
# Current Batch: 21
# Epoch: [4/1000], Batch 21, Loss : 109927880.0000
# Current Batch: 22
# Epoch: [4/1000], Batch 22, Loss : 152408944.0000
# Current Batch: 23
# Epoch: [4/1000], Batch 23, Loss : 259765152.0000
# Current Batch: 24
# Epoch: [4/1000], Batch 24, Loss : 137661888.0000
# Current Batch: 25
# Epoch: [4/1000], Batch 25, Loss : 161156192.0000
# Current Batch: 26
# Epoch: [4/1000], Batch 26, Loss : 109931984.0000
# Current Batch: 27
# Epoch: [4/1000], Batch 27, Loss : 131386944.0000
# Current Batch: 28
# Epoch: [4/1000], Batch 28, Loss : 107028080.0000
# Current Batch: 29
# Epoch: [4/1000], Batch 29, Loss : 153173504.0000
# Current Batch: 30
# Epoch: [4/1000], Batch 30, Loss : 162819952.0000
# Current Batch: 31
# Epoch: [4/1000], Batch 31, Loss : 98588520.0000
# Current Batch: 32
# Epoch: [4/1000], Batch 32, Loss : 176847104.0000
# Current Batch: 33
# Epoch: [4/1000], Batch 33, Loss : 161425952.0000
# Current Batch: 34
# Epoch: [4/1000], Batch 34, Loss : 192745888.0000
# Current Batch: 1
# Epoch: [5/1000], Batch 1, Loss : 182781216.0000
# Current Batch: 2
# Epoch: [5/1000], Batch 2, Loss : 101708416.0000
# Current Batch: 3
# Epoch: [5/1000], Batch 3, Loss : 155967472.0000
# Current Batch: 4
# Epoch: [5/1000], Batch 4, Loss : 108412144.0000
# Current Batch: 5
# Epoch: [5/1000], Batch 5, Loss : 98447840.0000
# Current Batch: 6
# Epoch: [5/1000], Batch 6, Loss : 93580000.0000
# Current Batch: 7
# Epoch: [5/1000], Batch 7, Loss : 105350624.0000
# Current Batch: 8
# Epoch: [5/1000], Batch 8, Loss : 59535212.0000
# Current Batch: 9
# Epoch: [5/1000], Batch 9, Loss : 192726400.0000
# Current Batch: 10
# Epoch: [5/1000], Batch 10, Loss : 150445840.0000
# Current Batch: 11
# Epoch: [5/1000], Batch 11, Loss : 85917472.0000
# Current Batch: 12
# Epoch: [5/1000], Batch 12, Loss : 109639720.0000
# Current Batch: 13
# Epoch: [5/1000], Batch 13, Loss : 159942480.0000
# Current Batch: 14
# Epoch: [5/1000], Batch 14, Loss : 144078944.0000
# Current Batch: 15
# Epoch: [5/1000], Batch 15, Loss : 86075264.0000
# Current Batch: 16
# Epoch: [5/1000], Batch 16, Loss : 116825360.0000
# Current Batch: 17
# Epoch: [5/1000], Batch 17, Loss : 112422208.0000
# Current Batch: 18
# Epoch: [5/1000], Batch 18, Loss : 119407472.0000
# Current Batch: 19
# Epoch: [5/1000], Batch 19, Loss : 138839312.0000
# Current Batch: 20
# Epoch: [5/1000], Batch 20, Loss : 123605520.0000
# Current Batch: 21
# Epoch: [5/1000], Batch 21, Loss : 103088704.0000
# Current Batch: 22
# Epoch: [5/1000], Batch 22, Loss : 196491568.0000
# Current Batch: 23
# Epoch: [5/1000], Batch 23, Loss : 127852168.0000
# Current Batch: 24
# Epoch: [5/1000], Batch 24, Loss : 178071392.0000
# Current Batch: 25
# Epoch: [5/1000], Batch 25, Loss : 126582984.0000
# Current Batch: 26
# Epoch: [5/1000], Batch 26, Loss : 208150944.0000
# Current Batch: 27
# Epoch: [5/1000], Batch 27, Loss : 269840640.0000
# Current Batch: 28
# Epoch: [5/1000], Batch 28, Loss : 277384096.0000
# Current Batch: 29
# Epoch: [5/1000], Batch 29, Loss : 140482160.0000
# Current Batch: 30
# Epoch: [5/1000], Batch 30, Loss : 111069408.0000
# Current Batch: 31
# Epoch: [5/1000], Batch 31, Loss : 76176536.0000
# Current Batch: 32
# Epoch: [5/1000], Batch 32, Loss : 221966736.0000
# Current Batch: 33
# Epoch: [5/1000], Batch 33, Loss : 207389936.0000
# Current Batch: 34
# Epoch: [5/1000], Batch 34, Loss : 328579936.0000
# Current Batch: 1
# Epoch: [6/1000], Batch 1, Loss : 168022624.0000
# Current Batch: 2
# Epoch: [6/1000], Batch 2, Loss : 103133048.0000
# Current Batch: 3
# Epoch: [6/1000], Batch 3, Loss : 135880496.0000
# Current Batch: 4
# Epoch: [6/1000], Batch 4, Loss : 212190416.0000
# Current Batch: 5
# Epoch: [6/1000], Batch 5, Loss : 190839968.0000
# Current Batch: 6
# Epoch: [6/1000], Batch 6, Loss : 131493408.0000
# Current Batch: 7
# Epoch: [6/1000], Batch 7, Loss : 137369024.0000
# Current Batch: 8
# Epoch: [6/1000], Batch 8, Loss : 56741444.0000
# Current Batch: 9
# Epoch: [6/1000], Batch 9, Loss : 111208936.0000
# Current Batch: 10
# Epoch: [6/1000], Batch 10, Loss : 123742736.0000
# Current Batch: 11
# Epoch: [6/1000], Batch 11, Loss : 227069888.0000
# Current Batch: 12
# Epoch: [6/1000], Batch 12, Loss : 117775992.0000
# Current Batch: 13
# Epoch: [6/1000], Batch 13, Loss : 107310928.0000
# Current Batch: 14
# Epoch: [6/1000], Batch 14, Loss : 157981520.0000
# Current Batch: 15
# Epoch: [6/1000], Batch 15, Loss : 128381808.0000
# Current Batch: 16
# Epoch: [6/1000], Batch 16, Loss : 238386080.0000
# Current Batch: 17
# Epoch: [6/1000], Batch 17, Loss : 133911504.0000
# Current Batch: 18
# Epoch: [6/1000], Batch 18, Loss : 183843904.0000
# Current Batch: 19
# Epoch: [6/1000], Batch 19, Loss : 117008352.0000
# Current Batch: 20
# Epoch: [6/1000], Batch 20, Loss : 143258416.0000
# Current Batch: 21
# Epoch: [6/1000], Batch 21, Loss : 262382080.0000
# Current Batch: 22
# Epoch: [6/1000], Batch 22, Loss : 60684344.0000
# Current Batch: 23
# Epoch: [6/1000], Batch 23, Loss : 84484816.0000
# Current Batch: 24
# Epoch: [6/1000], Batch 24, Loss : 111749440.0000
# Current Batch: 25
# Epoch: [6/1000], Batch 25, Loss : 173625472.0000
# Current Batch: 26
# Epoch: [6/1000], Batch 26, Loss : 63588324.0000
# Current Batch: 27
# Epoch: [6/1000], Batch 27, Loss : 233819216.0000
# Current Batch: 28
# Epoch: [6/1000], Batch 28, Loss : 84169840.0000
# Current Batch: 29
# Epoch: [6/1000], Batch 29, Loss : 93095616.0000
# Current Batch: 30
# Epoch: [6/1000], Batch 30, Loss : 157365168.0000
# Current Batch: 31
# Epoch: [6/1000], Batch 31, Loss : 166515824.0000
# Current Batch: 32
# Epoch: [6/1000], Batch 32, Loss : 221147712.0000
# Current Batch: 33
# Epoch: [6/1000], Batch 33, Loss : 171210000.0000
# Current Batch: 34
# Epoch: [6/1000], Batch 34, Loss : 68319664.0000
# Current Batch: 1
# Epoch: [7/1000], Batch 1, Loss : 156087344.0000
# Current Batch: 2
# Epoch: [7/1000], Batch 2, Loss : 117246928.0000
# Current Batch: 3
# Epoch: [7/1000], Batch 3, Loss : 125664496.0000
# Current Batch: 4
# Epoch: [7/1000], Batch 4, Loss : 150547648.0000
# Current Batch: 5
# Epoch: [7/1000], Batch 5, Loss : 136996128.0000
# Current Batch: 6
# Epoch: [7/1000], Batch 6, Loss : 203013856.0000
# Current Batch: 7
# Epoch: [7/1000], Batch 7, Loss : 160956320.0000
# Current Batch: 8
# Epoch: [7/1000], Batch 8, Loss : 153780544.0000
# Current Batch: 9
# Epoch: [7/1000], Batch 9, Loss : 88177096.0000
# Current Batch: 10
# Epoch: [7/1000], Batch 10, Loss : 274191072.0000
# Current Batch: 11
# Epoch: [7/1000], Batch 11, Loss : 98380864.0000
# Current Batch: 12
# Epoch: [7/1000], Batch 12, Loss : 154468624.0000
# Current Batch: 13
# Epoch: [7/1000], Batch 13, Loss : 141356736.0000
# Current Batch: 14
# Epoch: [7/1000], Batch 14, Loss : 192794848.0000
# Current Batch: 15
# Epoch: [7/1000], Batch 15, Loss : 125886048.0000
# Current Batch: 16
# Epoch: [7/1000], Batch 16, Loss : 86012808.0000
# Current Batch: 17
# Epoch: [7/1000], Batch 17, Loss : 114160048.0000
# Current Batch: 18
# Epoch: [7/1000], Batch 18, Loss : 162912032.0000
# Current Batch: 19
# Epoch: [7/1000], Batch 19, Loss : 105229768.0000
# Current Batch: 20
# Epoch: [7/1000], Batch 20, Loss : 184664512.0000
# Current Batch: 21
# Epoch: [7/1000], Batch 21, Loss : 100437232.0000
# Current Batch: 22
# Epoch: [7/1000], Batch 22, Loss : 137636944.0000
# Current Batch: 23
# Epoch: [7/1000], Batch 23, Loss : 82848264.0000
# Current Batch: 24
# Epoch: [7/1000], Batch 24, Loss : 146697024.0000
# Current Batch: 25
# Epoch: [7/1000], Batch 25, Loss : 122331552.0000
# Current Batch: 26
# Epoch: [7/1000], Batch 26, Loss : 140673152.0000
# Current Batch: 27
# Epoch: [7/1000], Batch 27, Loss : 199459024.0000
# Current Batch: 28
# Epoch: [7/1000], Batch 28, Loss : 227379424.0000
# Current Batch: 29
# Epoch: [7/1000], Batch 29, Loss : 95052320.0000
# Current Batch: 30
# Epoch: [7/1000], Batch 30, Loss : 172220208.0000
# Current Batch: 31
# Epoch: [7/1000], Batch 31, Loss : 102991160.0000
# Current Batch: 32
# Epoch: [7/1000], Batch 32, Loss : 79466568.0000
# Current Batch: 33
# Epoch: [7/1000], Batch 33, Loss : 184865424.0000
# Current Batch: 34
# Epoch: [7/1000], Batch 34, Loss : 247189040.0000
# Current Batch: 1
# Epoch: [8/1000], Batch 1, Loss : 161316128.0000
# Current Batch: 2
# Epoch: [8/1000], Batch 2, Loss : 105229088.0000
# Current Batch: 3
# Epoch: [8/1000], Batch 3, Loss : 96376728.0000
# Current Batch: 4
# Epoch: [8/1000], Batch 4, Loss : 106303840.0000
# Current Batch: 5
# Epoch: [8/1000], Batch 5, Loss : 132331432.0000
# Current Batch: 6
# Epoch: [8/1000], Batch 6, Loss : 63817476.0000
# Current Batch: 7
# Epoch: [8/1000], Batch 7, Loss : 165362048.0000
# Current Batch: 8
# Epoch: [8/1000], Batch 8, Loss : 109551688.0000
# Current Batch: 9
# Epoch: [8/1000], Batch 9, Loss : 148501344.0000
# Current Batch: 10
# Epoch: [8/1000], Batch 10, Loss : 160116848.0000
# Current Batch: 11
# Epoch: [8/1000], Batch 11, Loss : 176422032.0000
# Current Batch: 12
# Epoch: [8/1000], Batch 12, Loss : 145425008.0000
# Current Batch: 13
# Epoch: [8/1000], Batch 13, Loss : 91927888.0000
# Current Batch: 14
# Epoch: [8/1000], Batch 14, Loss : 192326336.0000
# Current Batch: 15
# Epoch: [8/1000], Batch 15, Loss : 144736976.0000
# Current Batch: 16
# Epoch: [8/1000], Batch 16, Loss : 204383024.0000
# Current Batch: 17
# Epoch: [8/1000], Batch 17, Loss : 206091680.0000
# Current Batch: 18
# Epoch: [8/1000], Batch 18, Loss : 183562432.0000
# Current Batch: 19
# Epoch: [8/1000], Batch 19, Loss : 139223744.0000
# Current Batch: 20
# Epoch: [8/1000], Batch 20, Loss : 83218904.0000
# Current Batch: 21
# Epoch: [8/1000], Batch 21, Loss : 172129360.0000
# Current Batch: 22
# Epoch: [8/1000], Batch 22, Loss : 89371200.0000
# Current Batch: 23
# Epoch: [8/1000], Batch 23, Loss : 196472256.0000
# Current Batch: 24
# Epoch: [8/1000], Batch 24, Loss : 165958704.0000
# Current Batch: 25
# Epoch: [8/1000], Batch 25, Loss : 162718160.0000
# Current Batch: 26
# Epoch: [8/1000], Batch 26, Loss : 130743888.0000
# Current Batch: 27
# Epoch: [8/1000], Batch 27, Loss : 209839952.0000
# Current Batch: 28
# Epoch: [8/1000], Batch 28, Loss : 135883616.0000
# Current Batch: 29
# Epoch: [8/1000], Batch 29, Loss : 99963864.0000
# Current Batch: 30
# Epoch: [8/1000], Batch 30, Loss : 176406288.0000
# Current Batch: 31
# Epoch: [8/1000], Batch 31, Loss : 146414032.0000
# Current Batch: 32
# Epoch: [8/1000], Batch 32, Loss : 92460944.0000
# Current Batch: 33
# Epoch: [8/1000], Batch 33, Loss : 135686528.0000
# Current Batch: 34
# Epoch: [8/1000], Batch 34, Loss : 239435232.0000
# Current Batch: 1
# Epoch: [9/1000], Batch 1, Loss : 173430608.0000
# Current Batch: 2
# Epoch: [9/1000], Batch 2, Loss : 127268384.0000
# Current Batch: 3
# Epoch: [9/1000], Batch 3, Loss : 280261312.0000
# Current Batch: 4
# Epoch: [9/1000], Batch 4, Loss : 191420480.0000
# Current Batch: 5
# Epoch: [9/1000], Batch 5, Loss : 152387584.0000
# Current Batch: 6
# Epoch: [9/1000], Batch 6, Loss : 91992408.0000
# Current Batch: 7
# Epoch: [9/1000], Batch 7, Loss : 87398200.0000
# Current Batch: 8
# Epoch: [9/1000], Batch 8, Loss : 86688016.0000
# Current Batch: 9
# Epoch: [9/1000], Batch 9, Loss : 44542848.0000
# Current Batch: 10
# Epoch: [9/1000], Batch 10, Loss : 140532912.0000
# Current Batch: 11
# Epoch: [9/1000], Batch 11, Loss : 155250688.0000
# Current Batch: 12
# Epoch: [9/1000], Batch 12, Loss : 198682816.0000
# Current Batch: 13
# Epoch: [9/1000], Batch 13, Loss : 265792480.0000
# Current Batch: 14
# Epoch: [9/1000], Batch 14, Loss : 77406880.0000
# Current Batch: 15
# Epoch: [9/1000], Batch 15, Loss : 130927632.0000
# Current Batch: 16
# Epoch: [9/1000], Batch 16, Loss : 98244640.0000
# Current Batch: 17
# Epoch: [9/1000], Batch 17, Loss : 132683632.0000
# Current Batch: 18
# Epoch: [9/1000], Batch 18, Loss : 109996504.0000
# Current Batch: 19
# Epoch: [9/1000], Batch 19, Loss : 81520736.0000
# Current Batch: 20
# Epoch: [9/1000], Batch 20, Loss : 119582768.0000
# Current Batch: 21
# Epoch: [9/1000], Batch 21, Loss : 147747984.0000
# Current Batch: 22
# Epoch: [9/1000], Batch 22, Loss : 93998592.0000
# Current Batch: 23
# Epoch: [9/1000], Batch 23, Loss : 120690720.0000
# Current Batch: 24
# Epoch: [9/1000], Batch 24, Loss : 122977976.0000
# Current Batch: 25
# Epoch: [9/1000], Batch 25, Loss : 199540864.0000
# Current Batch: 26
# Epoch: [9/1000], Batch 26, Loss : 80630368.0000
# Current Batch: 27
# Epoch: [9/1000], Batch 27, Loss : 219882192.0000
# Current Batch: 28
# Epoch: [9/1000], Batch 28, Loss : 344426208.0000
# Current Batch: 29
# Epoch: [9/1000], Batch 29, Loss : 169002336.0000
# Current Batch: 30
# Epoch: [9/1000], Batch 30, Loss : 141910528.0000
# Current Batch: 31
# Epoch: [9/1000], Batch 31, Loss : 115485616.0000
# Current Batch: 32
# Epoch: [9/1000], Batch 32, Loss : 183022544.0000
# Current Batch: 33
# Epoch: [9/1000], Batch 33, Loss : 114143888.0000
# Current Batch: 34
# Epoch: [9/1000], Batch 34, Loss : 132909912.0000
# Current Batch: 1
# Epoch: [10/1000], Batch 1, Loss : 180899472.0000
# Current Batch: 2
# Epoch: [10/1000], Batch 2, Loss : 186454096.0000
# Current Batch: 3
# Epoch: [10/1000], Batch 3, Loss : 97531928.0000
# Current Batch: 4
# Epoch: [10/1000], Batch 4, Loss : 128303368.0000
# Current Batch: 5
# Epoch: [10/1000], Batch 5, Loss : 133428176.0000
# Current Batch: 6
# Epoch: [10/1000], Batch 6, Loss : 125240744.0000
# Current Batch: 7
# Epoch: [10/1000], Batch 7, Loss : 122756272.0000
# Current Batch: 8
# Epoch: [10/1000], Batch 8, Loss : 51431240.0000
# Current Batch: 9
# Epoch: [10/1000], Batch 9, Loss : 176674448.0000
# Current Batch: 10
# Epoch: [10/1000], Batch 10, Loss : 199110384.0000
# Current Batch: 11
# Epoch: [10/1000], Batch 11, Loss : 188304128.0000
# Current Batch: 12
# Epoch: [10/1000], Batch 12, Loss : 125674592.0000
# Current Batch: 13
# Epoch: [10/1000], Batch 13, Loss : 56252336.0000
# Current Batch: 14
# Epoch: [10/1000], Batch 14, Loss : 114971192.0000
# Current Batch: 15
# Epoch: [10/1000], Batch 15, Loss : 87765752.0000
# Current Batch: 16
# Epoch: [10/1000], Batch 16, Loss : 192650816.0000
# Current Batch: 17
# Epoch: [10/1000], Batch 17, Loss : 130595968.0000
# Current Batch: 18
# Epoch: [10/1000], Batch 18, Loss : 82295528.0000
# Current Batch: 19
# Epoch: [10/1000], Batch 19, Loss : 220519424.0000
# Current Batch: 20
# Epoch: [10/1000], Batch 20, Loss : 163282608.0000
# Current Batch: 21
# Epoch: [10/1000], Batch 21, Loss : 107996256.0000
# Current Batch: 22
# Epoch: [10/1000], Batch 22, Loss : 193991264.0000
# Current Batch: 23
# Epoch: [10/1000], Batch 23, Loss : 165652480.0000
# Current Batch: 24
# Epoch: [10/1000], Batch 24, Loss : 172226512.0000
# Current Batch: 25
# Epoch: [10/1000], Batch 25, Loss : 219287024.0000
# Current Batch: 26
# Epoch: [10/1000], Batch 26, Loss : 99915896.0000
# Current Batch: 27
# Epoch: [10/1000], Batch 27, Loss : 173633680.0000
# Current Batch: 28
# Epoch: [10/1000], Batch 28, Loss : 107875856.0000
# Current Batch: 29
# Epoch: [10/1000], Batch 29, Loss : 108015344.0000
# Current Batch: 30
# Epoch: [10/1000], Batch 30, Loss : 111386608.0000
# Current Batch: 31
# Epoch: [10/1000], Batch 31, Loss : 292225152.0000
# Current Batch: 32
# Epoch: [10/1000], Batch 32, Loss : 183499856.0000
# Current Batch: 33
# Epoch: [10/1000], Batch 33, Loss : 80416384.0000
# Current Batch: 34
# Epoch: [10/1000], Batch 34, Loss : 135065760.0000
# Current Batch: 1
# Epoch: [11/1000], Batch 1, Loss : 160994208.0000
# Current Batch: 2
# Epoch: [11/1000], Batch 2, Loss : 134251568.0000
# Current Batch: 3
# Epoch: [11/1000], Batch 3, Loss : 150529104.0000
# Current Batch: 4
# Epoch: [11/1000], Batch 4, Loss : 136238688.0000
# Current Batch: 5
# Epoch: [11/1000], Batch 5, Loss : 172237104.0000
# Current Batch: 6
# Epoch: [11/1000], Batch 6, Loss : 239549104.0000
# Current Batch: 7
# Epoch: [11/1000], Batch 7, Loss : 91256736.0000
# Current Batch: 8
# Epoch: [11/1000], Batch 8, Loss : 195414784.0000
# Current Batch: 9
# Epoch: [11/1000], Batch 9, Loss : 179530048.0000
# Current Batch: 10
# Epoch: [11/1000], Batch 10, Loss : 176470672.0000
# Current Batch: 11
# Epoch: [11/1000], Batch 11, Loss : 94961600.0000
# Current Batch: 12
# Epoch: [11/1000], Batch 12, Loss : 173449984.0000
# Current Batch: 13
# Epoch: [11/1000], Batch 13, Loss : 158095952.0000
# Current Batch: 14
# Epoch: [11/1000], Batch 14, Loss : 142126128.0000
# Current Batch: 15
# Epoch: [11/1000], Batch 15, Loss : 123254680.0000
# Current Batch: 16
# Epoch: [11/1000], Batch 16, Loss : 94840328.0000
# Current Batch: 17
# Epoch: [11/1000], Batch 17, Loss : 156619504.0000
# Current Batch: 18
# Epoch: [11/1000], Batch 18, Loss : 124389424.0000
# Current Batch: 19
# Epoch: [11/1000], Batch 19, Loss : 247800912.0000
# Current Batch: 20
# Epoch: [11/1000], Batch 20, Loss : 154531664.0000
# Current Batch: 21
# Epoch: [11/1000], Batch 21, Loss : 108302384.0000
# Current Batch: 22
# Epoch: [11/1000], Batch 22, Loss : 66467628.0000
# Current Batch: 23
# Epoch: [11/1000], Batch 23, Loss : 124613904.0000
# Current Batch: 24
# Epoch: [11/1000], Batch 24, Loss : 145802064.0000
# Current Batch: 25
# Epoch: [11/1000], Batch 25, Loss : 148090608.0000
# Current Batch: 26
# Epoch: [11/1000], Batch 26, Loss : 102081144.0000
# Current Batch: 27
# Epoch: [11/1000], Batch 27, Loss : 179973760.0000
# Current Batch: 28
# Epoch: [11/1000], Batch 28, Loss : 177671872.0000
# Current Batch: 29
# Epoch: [11/1000], Batch 29, Loss : 108134280.0000
# Current Batch: 30
# Epoch: [11/1000], Batch 30, Loss : 169569904.0000
# Current Batch: 31
# Epoch: [11/1000], Batch 31, Loss : 84124800.0000
# Current Batch: 32
# Epoch: [11/1000], Batch 32, Loss : 199835040.0000
# Current Batch: 33
# Epoch: [11/1000], Batch 33, Loss : 71777872.0000
# Current Batch: 34
# Epoch: [11/1000], Batch 34, Loss : 83562560.0000
# Current Batch: 1
# Epoch: [12/1000], Batch 1, Loss : 154847104.0000
# Current Batch: 2
# Epoch: [12/1000], Batch 2, Loss : 88870768.0000
# Current Batch: 3
# Epoch: [12/1000], Batch 3, Loss : 148719120.0000
# Current Batch: 4
# Epoch: [12/1000], Batch 4, Loss : 121296648.0000
# Current Batch: 5
# Epoch: [12/1000], Batch 5, Loss : 225878304.0000
# Current Batch: 6
# Epoch: [12/1000], Batch 6, Loss : 186759936.0000
# Current Batch: 7
# Epoch: [12/1000], Batch 7, Loss : 127305432.0000
# Current Batch: 8
# Epoch: [12/1000], Batch 8, Loss : 115624240.0000
# Current Batch: 9
# Epoch: [12/1000], Batch 9, Loss : 74493136.0000
# Current Batch: 10
# Epoch: [12/1000], Batch 10, Loss : 70568520.0000
# Current Batch: 11
# Epoch: [12/1000], Batch 11, Loss : 166232976.0000
# Current Batch: 12
# Epoch: [12/1000], Batch 12, Loss : 78330136.0000
# Current Batch: 13
# Epoch: [12/1000], Batch 13, Loss : 88245416.0000
# Current Batch: 14
# Epoch: [12/1000], Batch 14, Loss : 173814176.0000
# Current Batch: 15
# Epoch: [12/1000], Batch 15, Loss : 102187008.0000
# Current Batch: 16
# Epoch: [12/1000], Batch 16, Loss : 289779136.0000
# Current Batch: 17
# Epoch: [12/1000], Batch 17, Loss : 146619696.0000
# Current Batch: 18
# Epoch: [12/1000], Batch 18, Loss : 138424736.0000
# Current Batch: 19
# Epoch: [12/1000], Batch 19, Loss : 219991072.0000
# Current Batch: 20
# Epoch: [12/1000], Batch 20, Loss : 119498600.0000
# Current Batch: 21
# Epoch: [12/1000], Batch 21, Loss : 88620552.0000
# Current Batch: 22
# Epoch: [12/1000], Batch 22, Loss : 224219120.0000
# Current Batch: 23
# Epoch: [12/1000], Batch 23, Loss : 210370992.0000
# Current Batch: 24
# Epoch: [12/1000], Batch 24, Loss : 137918720.0000
# Current Batch: 25
# Epoch: [12/1000], Batch 25, Loss : 197048544.0000
# Current Batch: 26
# Epoch: [12/1000], Batch 26, Loss : 178567552.0000
# Current Batch: 27
# Epoch: [12/1000], Batch 27, Loss : 83882984.0000
# Current Batch: 28
# Epoch: [12/1000], Batch 28, Loss : 167396128.0000
# Current Batch: 29
# Epoch: [12/1000], Batch 29, Loss : 149689296.0000
# Current Batch: 30
# Epoch: [12/1000], Batch 30, Loss : 91825424.0000
# Current Batch: 31
# Epoch: [12/1000], Batch 31, Loss : 112678264.0000
# Current Batch: 32
# Epoch: [12/1000], Batch 32, Loss : 110637952.0000
# Current Batch: 33
# Epoch: [12/1000], Batch 33, Loss : 185060096.0000
# Current Batch: 34
# Epoch: [12/1000], Batch 34, Loss : 165332448.0000
# Current Batch: 1
# Epoch: [13/1000], Batch 1, Loss : 114064008.0000
# Current Batch: 2
# Epoch: [13/1000], Batch 2, Loss : 109897216.0000
# Current Batch: 3
# Epoch: [13/1000], Batch 3, Loss : 183630896.0000
# Current Batch: 4
# Epoch: [13/1000], Batch 4, Loss : 119865600.0000
# Current Batch: 5
# Epoch: [13/1000], Batch 5, Loss : 80190856.0000
# Current Batch: 6
# Epoch: [13/1000], Batch 6, Loss : 76612984.0000
# Current Batch: 7
# Epoch: [13/1000], Batch 7, Loss : 131849632.0000
# Current Batch: 8
# Epoch: [13/1000], Batch 8, Loss : 132097352.0000
# Current Batch: 9
# Epoch: [13/1000], Batch 9, Loss : 142365296.0000
# Current Batch: 10
# Epoch: [13/1000], Batch 10, Loss : 177331296.0000
# Current Batch: 11
# Epoch: [13/1000], Batch 11, Loss : 205600256.0000
# Current Batch: 12
# Epoch: [13/1000], Batch 12, Loss : 131488536.0000
# Current Batch: 13
# Epoch: [13/1000], Batch 13, Loss : 255709504.0000
# Current Batch: 14
# Epoch: [13/1000], Batch 14, Loss : 157521216.0000
# Current Batch: 15
# Epoch: [13/1000], Batch 15, Loss : 101750288.0000
# Current Batch: 16
# Epoch: [13/1000], Batch 16, Loss : 155128912.0000
# Current Batch: 17
# Epoch: [13/1000], Batch 17, Loss : 95136696.0000
# Current Batch: 18
# Epoch: [13/1000], Batch 18, Loss : 146176256.0000
# Current Batch: 19
# Epoch: [13/1000], Batch 19, Loss : 91765408.0000
# Current Batch: 20
# Epoch: [13/1000], Batch 20, Loss : 171458304.0000
# Current Batch: 21
# Epoch: [13/1000], Batch 21, Loss : 124814480.0000
# Current Batch: 22
# Epoch: [13/1000], Batch 22, Loss : 197949472.0000
# Current Batch: 23
# Epoch: [13/1000], Batch 23, Loss : 146819120.0000
# Current Batch: 24
# Epoch: [13/1000], Batch 24, Loss : 161348352.0000
# Current Batch: 25
# Epoch: [13/1000], Batch 25, Loss : 150718992.0000
# Current Batch: 26
# Epoch: [13/1000], Batch 26, Loss : 238403696.0000
# Current Batch: 27
# Epoch: [13/1000], Batch 27, Loss : 105324976.0000
# Current Batch: 28
# Epoch: [13/1000], Batch 28, Loss : 97835632.0000
# Current Batch: 29
# Epoch: [13/1000], Batch 29, Loss : 91585976.0000
# Current Batch: 30
# Epoch: [13/1000], Batch 30, Loss : 178516304.0000
# Current Batch: 31
# Epoch: [13/1000], Batch 31, Loss : 207111136.0000
# Current Batch: 32
# Epoch: [13/1000], Batch 32, Loss : 132058160.0000
# Current Batch: 33
# Epoch: [13/1000], Batch 33, Loss : 133111336.0000
# Current Batch: 34
# Epoch: [13/1000], Batch 34, Loss : 203519728.0000
# Current Batch: 1
# Epoch: [14/1000], Batch 1, Loss : 246091072.0000
# Current Batch: 2
# Epoch: [14/1000], Batch 2, Loss : 126136440.0000
# Current Batch: 3
# Epoch: [14/1000], Batch 3, Loss : 83599368.0000
# Current Batch: 4
# Epoch: [14/1000], Batch 4, Loss : 96628440.0000
# Current Batch: 5
# Epoch: [14/1000], Batch 5, Loss : 133394640.0000
# Current Batch: 6
# Epoch: [14/1000], Batch 6, Loss : 137901920.0000
# Current Batch: 7
# Epoch: [14/1000], Batch 7, Loss : 102072480.0000
# Current Batch: 8
# Epoch: [14/1000], Batch 8, Loss : 151503152.0000
# Current Batch: 9
# Epoch: [14/1000], Batch 9, Loss : 170559360.0000
# Current Batch: 10
# Epoch: [14/1000], Batch 10, Loss : 119085336.0000
# Current Batch: 11
# Epoch: [14/1000], Batch 11, Loss : 190461744.0000
# Current Batch: 12
# Epoch: [14/1000], Batch 12, Loss : 242145552.0000
# Current Batch: 13
# Epoch: [14/1000], Batch 13, Loss : 70253392.0000
# Current Batch: 14
# Epoch: [14/1000], Batch 14, Loss : 84427480.0000
# Current Batch: 15
# Epoch: [14/1000], Batch 15, Loss : 125054064.0000
# Current Batch: 16
# Epoch: [14/1000], Batch 16, Loss : 214797856.0000
# Current Batch: 17
# Epoch: [14/1000], Batch 17, Loss : 125205328.0000
# Current Batch: 18
# Epoch: [14/1000], Batch 18, Loss : 76462736.0000
# Current Batch: 19
# Epoch: [14/1000], Batch 19, Loss : 132275632.0000
# Current Batch: 20
# Epoch: [14/1000], Batch 20, Loss : 128667032.0000
# Current Batch: 21
# Epoch: [14/1000], Batch 21, Loss : 172069728.0000
# Current Batch: 22
# Epoch: [14/1000], Batch 22, Loss : 214937856.0000
# Current Batch: 23
# Epoch: [14/1000], Batch 23, Loss : 99707200.0000
# Current Batch: 24
# Epoch: [14/1000], Batch 24, Loss : 123250128.0000
# Current Batch: 25
# Epoch: [14/1000], Batch 25, Loss : 231210384.0000
# Current Batch: 26
# Epoch: [14/1000], Batch 26, Loss : 125948592.0000
# Current Batch: 27
# Epoch: [14/1000], Batch 27, Loss : 107615088.0000
# Current Batch: 28
# Epoch: [14/1000], Batch 28, Loss : 178045968.0000
# Current Batch: 29
# Epoch: [14/1000], Batch 29, Loss : 153828336.0000
# Current Batch: 30
# Epoch: [14/1000], Batch 30, Loss : 105325104.0000
# Current Batch: 31
# Epoch: [14/1000], Batch 31, Loss : 188910144.0000
# Current Batch: 32
# Epoch: [14/1000], Batch 32, Loss : 192633200.0000
# Current Batch: 33
# Epoch: [14/1000], Batch 33, Loss : 111068560.0000
# Current Batch: 34
# Epoch: [14/1000], Batch 34, Loss : 168141664.0000
# Current Batch: 1
# Epoch: [15/1000], Batch 1, Loss : 141423088.0000
# Current Batch: 2
# Epoch: [15/1000], Batch 2, Loss : 124024184.0000
# Current Batch: 3
# Epoch: [15/1000], Batch 3, Loss : 94176736.0000
# Current Batch: 4
# Epoch: [15/1000], Batch 4, Loss : 186675024.0000
# Current Batch: 5
# Epoch: [15/1000], Batch 5, Loss : 247144304.0000
# Current Batch: 6
# Epoch: [15/1000], Batch 6, Loss : 131517248.0000
# Current Batch: 7
# Epoch: [15/1000], Batch 7, Loss : 115177744.0000
# Current Batch: 8
# Epoch: [15/1000], Batch 8, Loss : 96564944.0000
# Current Batch: 9
# Epoch: [15/1000], Batch 9, Loss : 121194184.0000
# Current Batch: 10
# Epoch: [15/1000], Batch 10, Loss : 174873216.0000
# Current Batch: 11
# Epoch: [15/1000], Batch 11, Loss : 121212120.0000
# Current Batch: 12
# Epoch: [15/1000], Batch 12, Loss : 158625344.0000
# Current Batch: 13
# Epoch: [15/1000], Batch 13, Loss : 206247776.0000
# Current Batch: 14
# Epoch: [15/1000], Batch 14, Loss : 162037184.0000
# Current Batch: 15
# Epoch: [15/1000], Batch 15, Loss : 78017744.0000
# Current Batch: 16
# Epoch: [15/1000], Batch 16, Loss : 69452008.0000
# Current Batch: 17
# Epoch: [15/1000], Batch 17, Loss : 138879488.0000
# Current Batch: 18
# Epoch: [15/1000], Batch 18, Loss : 156807456.0000
# Current Batch: 19
# Epoch: [15/1000], Batch 19, Loss : 160567360.0000
# Current Batch: 20
# Epoch: [15/1000], Batch 20, Loss : 115530832.0000
# Current Batch: 21
# Epoch: [15/1000], Batch 21, Loss : 153919344.0000
# Current Batch: 22
# Epoch: [15/1000], Batch 22, Loss : 234981632.0000
# Current Batch: 23
# Epoch: [15/1000], Batch 23, Loss : 130325528.0000
# Current Batch: 24
# Epoch: [15/1000], Batch 24, Loss : 158130192.0000
# Current Batch: 25
# Epoch: [15/1000], Batch 25, Loss : 133498704.0000
# Current Batch: 26
# Epoch: [15/1000], Batch 26, Loss : 217722352.0000
# Current Batch: 27
# Epoch: [15/1000], Batch 27, Loss : 104200168.0000
# Current Batch: 28
# Epoch: [15/1000], Batch 28, Loss : 134162232.0000
# Current Batch: 29
# Epoch: [15/1000], Batch 29, Loss : 130273008.0000
# Current Batch: 30
# Epoch: [15/1000], Batch 30, Loss : 178683872.0000
# Current Batch: 31
# Epoch: [15/1000], Batch 31, Loss : 183561744.0000
# Current Batch: 32
# Epoch: [15/1000], Batch 32, Loss : 160016960.0000
# Current Batch: 33
# Epoch: [15/1000], Batch 33, Loss : 81313128.0000
# Current Batch: 34
# Epoch: [15/1000], Batch 34, Loss : 59222204.0000
# Current Batch: 1
# Epoch: [16/1000], Batch 1, Loss : 78139968.0000
# Current Batch: 2
# Epoch: [16/1000], Batch 2, Loss : 126524656.0000
# Current Batch: 3
# Epoch: [16/1000], Batch 3, Loss : 97995184.0000
# Current Batch: 4
# Epoch: [16/1000], Batch 4, Loss : 196912832.0000
# Current Batch: 5
# Epoch: [16/1000], Batch 5, Loss : 132565192.0000
# Current Batch: 6
# Epoch: [16/1000], Batch 6, Loss : 83185432.0000
# Current Batch: 7
# Epoch: [16/1000], Batch 7, Loss : 58232636.0000
# Current Batch: 8
# Epoch: [16/1000], Batch 8, Loss : 157165776.0000
# Current Batch: 9
# Epoch: [16/1000], Batch 9, Loss : 113013784.0000
# Current Batch: 10
# Epoch: [16/1000], Batch 10, Loss : 135293616.0000
# Current Batch: 11
# Epoch: [16/1000], Batch 11, Loss : 176406512.0000
# Current Batch: 12
# Epoch: [16/1000], Batch 12, Loss : 92005872.0000
# Current Batch: 13
# Epoch: [16/1000], Batch 13, Loss : 106315280.0000
# Current Batch: 14
# Epoch: [16/1000], Batch 14, Loss : 150874352.0000
# Current Batch: 15
# Epoch: [16/1000], Batch 15, Loss : 168288096.0000
# Current Batch: 16
# Epoch: [16/1000], Batch 16, Loss : 184220240.0000
# Current Batch: 17
# Epoch: [16/1000], Batch 17, Loss : 123605936.0000
# Current Batch: 18
# Epoch: [16/1000], Batch 18, Loss : 142840448.0000
# Current Batch: 19
# Epoch: [16/1000], Batch 19, Loss : 182978384.0000
# Current Batch: 20
# Epoch: [16/1000], Batch 20, Loss : 278483488.0000
# Current Batch: 21
# Epoch: [16/1000], Batch 21, Loss : 192993392.0000
# Current Batch: 22
# Epoch: [16/1000], Batch 22, Loss : 204167920.0000
# Current Batch: 23
# Epoch: [16/1000], Batch 23, Loss : 190105904.0000
# Current Batch: 24
# Epoch: [16/1000], Batch 24, Loss : 101861448.0000
# Current Batch: 25
# Epoch: [16/1000], Batch 25, Loss : 111388592.0000
# Current Batch: 26
# Epoch: [16/1000], Batch 26, Loss : 112671480.0000
# Current Batch: 27
# Epoch: [16/1000], Batch 27, Loss : 123397184.0000
# Current Batch: 28
# Epoch: [16/1000], Batch 28, Loss : 94554712.0000
# Current Batch: 29
# Epoch: [16/1000], Batch 29, Loss : 145928480.0000
# Current Batch: 30
# Epoch: [16/1000], Batch 30, Loss : 244575056.0000
# Current Batch: 31
# Epoch: [16/1000], Batch 31, Loss : 112260960.0000
# Current Batch: 32
# Epoch: [16/1000], Batch 32, Loss : 121760544.0000
# Current Batch: 33
# Epoch: [16/1000], Batch 33, Loss : 246743904.0000
# Current Batch: 34
# Epoch: [16/1000], Batch 34, Loss : 112497704.0000
# Current Batch: 1
# Epoch: [17/1000], Batch 1, Loss : 199266240.0000
# Current Batch: 2
# Epoch: [17/1000], Batch 2, Loss : 69687064.0000
# Current Batch: 3
# Epoch: [17/1000], Batch 3, Loss : 168754864.0000
# Current Batch: 4
# Epoch: [17/1000], Batch 4, Loss : 162631568.0000
# Current Batch: 5
# Epoch: [17/1000], Batch 5, Loss : 136491840.0000
# Current Batch: 6
# Epoch: [17/1000], Batch 6, Loss : 120542248.0000
# Current Batch: 7
# Epoch: [17/1000], Batch 7, Loss : 198849104.0000
# Current Batch: 8
# Epoch: [17/1000], Batch 8, Loss : 170138592.0000
# Current Batch: 9
# Epoch: [17/1000], Batch 9, Loss : 131078424.0000
# Current Batch: 10
# Epoch: [17/1000], Batch 10, Loss : 156594912.0000
# Current Batch: 11
# Epoch: [17/1000], Batch 11, Loss : 114406024.0000
# Current Batch: 12
# Epoch: [17/1000], Batch 12, Loss : 94437520.0000
# Current Batch: 13
# Epoch: [17/1000], Batch 13, Loss : 233583552.0000
# Current Batch: 14
# Epoch: [17/1000], Batch 14, Loss : 116114240.0000
# Current Batch: 15
# Epoch: [17/1000], Batch 15, Loss : 205877968.0000
# Current Batch: 16
# Epoch: [17/1000], Batch 16, Loss : 150527632.0000
# Current Batch: 17
# Epoch: [17/1000], Batch 17, Loss : 139045280.0000
# Current Batch: 18
# Epoch: [17/1000], Batch 18, Loss : 171494976.0000
# Current Batch: 19
# Epoch: [17/1000], Batch 19, Loss : 164874512.0000
# Current Batch: 20
# Epoch: [17/1000], Batch 20, Loss : 175201200.0000
# Current Batch: 21
# Epoch: [17/1000], Batch 21, Loss : 181073344.0000
# Current Batch: 22
# Epoch: [17/1000], Batch 22, Loss : 87806232.0000
# Current Batch: 23
# Epoch: [17/1000], Batch 23, Loss : 156292112.0000
# Current Batch: 24
# Epoch: [17/1000], Batch 24, Loss : 190467536.0000
# Current Batch: 25
# Epoch: [17/1000], Batch 25, Loss : 156778528.0000
# Current Batch: 26
# Epoch: [17/1000], Batch 26, Loss : 115893584.0000
# Current Batch: 27
# Epoch: [17/1000], Batch 27, Loss : 163662560.0000
# Current Batch: 28
# Epoch: [17/1000], Batch 28, Loss : 123458008.0000
# Current Batch: 29
# Epoch: [17/1000], Batch 29, Loss : 87029208.0000
# Current Batch: 30
# Epoch: [17/1000], Batch 30, Loss : 78985344.0000
# Current Batch: 31
# Epoch: [17/1000], Batch 31, Loss : 168160720.0000
# Current Batch: 32
# Epoch: [17/1000], Batch 32, Loss : 97930480.0000
# Current Batch: 33
# Epoch: [17/1000], Batch 33, Loss : 91984816.0000
# Current Batch: 34
# Epoch: [17/1000], Batch 34, Loss : 129683888.0000
# Current Batch: 1
# Epoch: [18/1000], Batch 1, Loss : 90231976.0000
# Current Batch: 2
# Epoch: [18/1000], Batch 2, Loss : 162362672.0000
# Current Batch: 3
# Epoch: [18/1000], Batch 3, Loss : 126234416.0000
# Current Batch: 4
# Epoch: [18/1000], Batch 4, Loss : 196523440.0000
# Current Batch: 5
# Epoch: [18/1000], Batch 5, Loss : 97544528.0000
# Current Batch: 6
# Epoch: [18/1000], Batch 6, Loss : 138537568.0000
# Current Batch: 7
# Epoch: [18/1000], Batch 7, Loss : 165342352.0000
# Current Batch: 8
# Epoch: [18/1000], Batch 8, Loss : 158734624.0000
# Current Batch: 9
# Epoch: [18/1000], Batch 9, Loss : 158331680.0000
# Current Batch: 10
# Epoch: [18/1000], Batch 10, Loss : 179720512.0000
# Current Batch: 11
# Epoch: [18/1000], Batch 11, Loss : 264004048.0000
# Current Batch: 12
# Epoch: [18/1000], Batch 12, Loss : 144446688.0000
# Current Batch: 13
# Epoch: [18/1000], Batch 13, Loss : 196004000.0000
# Current Batch: 14
# Epoch: [18/1000], Batch 14, Loss : 132023488.0000
# Current Batch: 15
# Epoch: [18/1000], Batch 15, Loss : 131058072.0000
# Current Batch: 16
# Epoch: [18/1000], Batch 16, Loss : 181549616.0000
# Current Batch: 17
# Epoch: [18/1000], Batch 17, Loss : 137097040.0000
# Current Batch: 18
# Epoch: [18/1000], Batch 18, Loss : 163889840.0000
# Current Batch: 19
# Epoch: [18/1000], Batch 19, Loss : 158630944.0000
# Current Batch: 20
# Epoch: [18/1000], Batch 20, Loss : 71227912.0000
# Current Batch: 21
# Epoch: [18/1000], Batch 21, Loss : 168041472.0000
# Current Batch: 22
# Epoch: [18/1000], Batch 22, Loss : 91811552.0000
# Current Batch: 23
# Epoch: [18/1000], Batch 23, Loss : 111015320.0000
# Current Batch: 24
# Epoch: [18/1000], Batch 24, Loss : 187193168.0000
# Current Batch: 25
# Epoch: [18/1000], Batch 25, Loss : 127759392.0000
# Current Batch: 26
# Epoch: [18/1000], Batch 26, Loss : 118457552.0000
# Current Batch: 27
# Epoch: [18/1000], Batch 27, Loss : 58745828.0000
# Current Batch: 28
# Epoch: [18/1000], Batch 28, Loss : 192147664.0000
# Current Batch: 29
# Epoch: [18/1000], Batch 29, Loss : 142365008.0000
# Current Batch: 30
# Epoch: [18/1000], Batch 30, Loss : 167345280.0000
# Current Batch: 31
# Epoch: [18/1000], Batch 31, Loss : 126936160.0000
# Current Batch: 32
# Epoch: [18/1000], Batch 32, Loss : 105358048.0000
# Current Batch: 33
# Epoch: [18/1000], Batch 33, Loss : 165735488.0000
# Current Batch: 34
# Epoch: [18/1000], Batch 34, Loss : 39417212.0000
# Current Batch: 1
# Epoch: [19/1000], Batch 1, Loss : 211670272.0000
# Current Batch: 2
# Epoch: [19/1000], Batch 2, Loss : 106337104.0000
# Current Batch: 3
# Epoch: [19/1000], Batch 3, Loss : 110624944.0000
# Current Batch: 4
# Epoch: [19/1000], Batch 4, Loss : 157301184.0000
# Current Batch: 5
# Epoch: [19/1000], Batch 5, Loss : 57026844.0000
# Current Batch: 6
# Epoch: [19/1000], Batch 6, Loss : 100204024.0000
# Current Batch: 7
# Epoch: [19/1000], Batch 7, Loss : 198210480.0000
# Current Batch: 8
# Epoch: [19/1000], Batch 8, Loss : 65707820.0000
# Current Batch: 9
# Epoch: [19/1000], Batch 9, Loss : 119851520.0000
# Current Batch: 10
# Epoch: [19/1000], Batch 10, Loss : 131346384.0000
# Current Batch: 11
# Epoch: [19/1000], Batch 11, Loss : 111286304.0000
# Current Batch: 12
# Epoch: [19/1000], Batch 12, Loss : 237338752.0000
# Current Batch: 13
# Epoch: [19/1000], Batch 13, Loss : 95881224.0000
# Current Batch: 14
# Epoch: [19/1000], Batch 14, Loss : 162803840.0000
# Current Batch: 15
# Epoch: [19/1000], Batch 15, Loss : 149270704.0000
# Current Batch: 16
# Epoch: [19/1000], Batch 16, Loss : 182925664.0000
# Current Batch: 17
# Epoch: [19/1000], Batch 17, Loss : 267968528.0000
# Current Batch: 18
# Epoch: [19/1000], Batch 18, Loss : 260406416.0000
# Current Batch: 19
# Epoch: [19/1000], Batch 19, Loss : 108203440.0000
# Current Batch: 20
# Epoch: [19/1000], Batch 20, Loss : 201046848.0000
# Current Batch: 21
# Epoch: [19/1000], Batch 21, Loss : 95186504.0000
# Current Batch: 22
# Epoch: [19/1000], Batch 22, Loss : 136881920.0000
# Current Batch: 23
# Epoch: [19/1000], Batch 23, Loss : 117083192.0000
# Current Batch: 24
# Epoch: [19/1000], Batch 24, Loss : 102265624.0000
# Current Batch: 25
# Epoch: [19/1000], Batch 25, Loss : 117400624.0000
# Current Batch: 26
# Epoch: [19/1000], Batch 26, Loss : 127343560.0000
# Current Batch: 27
# Epoch: [19/1000], Batch 27, Loss : 175556496.0000
# Current Batch: 28
# Epoch: [19/1000], Batch 28, Loss : 93923240.0000
# Current Batch: 29
# Epoch: [19/1000], Batch 29, Loss : 115425368.0000
# Current Batch: 30
# Epoch: [19/1000], Batch 30, Loss : 218017600.0000
# Current Batch: 31
# Epoch: [19/1000], Batch 31, Loss : 101565536.0000
# Current Batch: 32
# Epoch: [19/1000], Batch 32, Loss : 192908384.0000
# Current Batch: 33
# Epoch: [19/1000], Batch 33, Loss : 165580384.0000
# Current Batch: 34
# Epoch: [19/1000], Batch 34, Loss : 97655104.0000
# Current Batch: 1
# Epoch: [20/1000], Batch 1, Loss : 126674912.0000
# Current Batch: 2
# Epoch: [20/1000], Batch 2, Loss : 142467504.0000
# Current Batch: 3
# Epoch: [20/1000], Batch 3, Loss : 133638304.0000
# Current Batch: 4
# Epoch: [20/1000], Batch 4, Loss : 102250160.0000
# Current Batch: 5
# Epoch: [20/1000], Batch 5, Loss : 207368000.0000
# Current Batch: 6
# Epoch: [20/1000], Batch 6, Loss : 87345408.0000
# Current Batch: 7
# Epoch: [20/1000], Batch 7, Loss : 112727104.0000
# Current Batch: 8
# Epoch: [20/1000], Batch 8, Loss : 195152224.0000
# Current Batch: 9
# Epoch: [20/1000], Batch 9, Loss : 149277536.0000
# Current Batch: 10
# Epoch: [20/1000], Batch 10, Loss : 200366960.0000
# Current Batch: 11
# Epoch: [20/1000], Batch 11, Loss : 195801680.0000
# Current Batch: 12
# Epoch: [20/1000], Batch 12, Loss : 154015552.0000
# Current Batch: 13
# Epoch: [20/1000], Batch 13, Loss : 136997360.0000
# Current Batch: 14
# Epoch: [20/1000], Batch 14, Loss : 165255104.0000
# Current Batch: 15
# Epoch: [20/1000], Batch 15, Loss : 140183856.0000
# Current Batch: 16
# Epoch: [20/1000], Batch 16, Loss : 117455184.0000
# Current Batch: 17
# Epoch: [20/1000], Batch 17, Loss : 138626576.0000
# Current Batch: 18
# Epoch: [20/1000], Batch 18, Loss : 126357280.0000
# Current Batch: 19
# Epoch: [20/1000], Batch 19, Loss : 137807280.0000
# Current Batch: 20
# Epoch: [20/1000], Batch 20, Loss : 135705216.0000
# Current Batch: 21
# Epoch: [20/1000], Batch 21, Loss : 124365432.0000
# Current Batch: 22
# Epoch: [20/1000], Batch 22, Loss : 154900128.0000
# Current Batch: 23
# Epoch: [20/1000], Batch 23, Loss : 96762992.0000
# Current Batch: 24
# Epoch: [20/1000], Batch 24, Loss : 217980032.0000
# Current Batch: 25
# Epoch: [20/1000], Batch 25, Loss : 108787272.0000
# Current Batch: 26
# Epoch: [20/1000], Batch 26, Loss : 145151008.0000
# Current Batch: 27
# Epoch: [20/1000], Batch 27, Loss : 156033664.0000
# Current Batch: 28
# Epoch: [20/1000], Batch 28, Loss : 121413112.0000
# Current Batch: 29
# Epoch: [20/1000], Batch 29, Loss : 168387488.0000
# Current Batch: 30
# Epoch: [20/1000], Batch 30, Loss : 160099776.0000
# Current Batch: 31
# Epoch: [20/1000], Batch 31, Loss : 113598776.0000
# Current Batch: 32
# Epoch: [20/1000], Batch 32, Loss : 189832224.0000
# Current Batch: 33
# Epoch: [20/1000], Batch 33, Loss : 145475056.0000
# Current Batch: 34
# Epoch: [20/1000], Batch 34, Loss : 56349868.0000
# Current Batch: 1
# Epoch: [21/1000], Batch 1, Loss : 244788000.0000
# Current Batch: 2
# Epoch: [21/1000], Batch 2, Loss : 91780496.0000
# Current Batch: 3
# Epoch: [21/1000], Batch 3, Loss : 234016448.0000
# Current Batch: 4
# Epoch: [21/1000], Batch 4, Loss : 133255792.0000
# Current Batch: 5
# Epoch: [21/1000], Batch 5, Loss : 124455176.0000
# Current Batch: 6
# Epoch: [21/1000], Batch 6, Loss : 73427664.0000
# Current Batch: 7
# Epoch: [21/1000], Batch 7, Loss : 96445760.0000
# Current Batch: 8
# Epoch: [21/1000], Batch 8, Loss : 97294392.0000
# Current Batch: 9
# Epoch: [21/1000], Batch 9, Loss : 89297112.0000
# Current Batch: 10
# Epoch: [21/1000], Batch 10, Loss : 89471240.0000
# Current Batch: 11
# Epoch: [21/1000], Batch 11, Loss : 53202112.0000
# Current Batch: 12
# Epoch: [21/1000], Batch 12, Loss : 174109296.0000
# Current Batch: 13
# Epoch: [21/1000], Batch 13, Loss : 135638752.0000
# Current Batch: 14
# Epoch: [21/1000], Batch 14, Loss : 144936720.0000
# Current Batch: 15
# Epoch: [21/1000], Batch 15, Loss : 142257808.0000
# Current Batch: 16
# Epoch: [21/1000], Batch 16, Loss : 128142776.0000
# Current Batch: 17
# Epoch: [21/1000], Batch 17, Loss : 150313680.0000
# Current Batch: 18
# Epoch: [21/1000], Batch 18, Loss : 134207544.0000
# Current Batch: 19
# Epoch: [21/1000], Batch 19, Loss : 135781472.0000
# Current Batch: 20
# Epoch: [21/1000], Batch 20, Loss : 227598080.0000
# Current Batch: 21
# Epoch: [21/1000], Batch 21, Loss : 119511360.0000
# Current Batch: 22
# Epoch: [21/1000], Batch 22, Loss : 156935232.0000
# Current Batch: 23
# Epoch: [21/1000], Batch 23, Loss : 96801304.0000
# Current Batch: 24
# Epoch: [21/1000], Batch 24, Loss : 286581664.0000
# Current Batch: 25
# Epoch: [21/1000], Batch 25, Loss : 154568112.0000
# Current Batch: 26
# Epoch: [21/1000], Batch 26, Loss : 242227968.0000
# Current Batch: 27
# ...
# Current Batch: 5
# Epoch: [132/1000], Batch 5, Loss : 77743648.0000
# Current Batch: 6
# Epoch: [132/1000], Batch 6, Loss : 187244032.0000
# Current Batch: 7
# Epoch: [132/1000], Batch 7, Loss : 130765472.0000
# Current Batch: 8
# Epoch: [132/1000], Batch 8, Loss : 195381984.0000
# Current Batch: 9
# Epoch: [132/1000], Batch 9, Loss : 208908416.0000
# Current Batch: 10
# Epoch: [132/1000], Batch 10, Loss : 174565232.0000
# Current Batch: 11
# Epoch: [132/1000], Batch 11, Loss : 159043312.0000
# Current Batch: 12
# Epoch: [132/1000], Batch 12, Loss : 95876696.0000
# Current Batch: 13
# Epoch: [132/1000], Batch 13, Loss : 156501904.0000
# Current Batch: 14
# Epoch: [132/1000], Batch 14, Loss : 110098992.0000
# Current Batch: 15
# Epoch: [132/1000], Batch 15, Loss : 221769568.0000
# Current Batch: 16
# Epoch: [132/1000], Batch 16, Loss : 97888264.0000
# Current Batch: 17
# Epoch: [132/1000], Batch 17, Loss : 163722176.0000
# Current Batch: 18
# Epoch: [132/1000], Batch 18, Loss : 145499152.0000
# Current Batch: 19
# Epoch: [132/1000], Batch 19, Loss : 112970752.0000
# Current Batch: 20
# Epoch: [132/1000], Batch 20, Loss : 84583864.0000
# Current Batch: 21
# Epoch: [132/1000], Batch 21, Loss : 203787408.0000
# Current Batch: 22
# Epoch: [132/1000], Batch 22, Loss : 98901208.0000
# Current Batch: 23
# Epoch: [132/1000], Batch 23, Loss : 138371680.0000
# Current Batch: 24
# Epoch: [132/1000], Batch 24, Loss : 62695132.0000
# Current Batch: 25
# Epoch: [132/1000], Batch 25, Loss : 129297712.0000
# Current Batch: 26
# Epoch: [132/1000], Batch 26, Loss : 152820064.0000
# Current Batch: 27
# Epoch: [132/1000], Batch 27, Loss : 174151056.0000
# Current Batch: 28
# Epoch: [132/1000], Batch 28, Loss : 157808528.0000
# Current Batch: 29
# Epoch: [132/1000], Batch 29, Loss : 127166928.0000
# Current Batch: 30
# Epoch: [132/1000], Batch 30, Loss : 102392280.0000
# Current Batch: 31
# Epoch: [132/1000], Batch 31, Loss : 162797184.0000
# Current Batch: 32
# Epoch: [132/1000], Batch 32, Loss : 160468288.0000
# Current Batch: 33
# Epoch: [132/1000], Batch 33, Loss : 218832256.0000
# Current Batch: 34
# Epoch: [132/1000], Batch 34, Loss : 161853504.0000
# Current Batch: 1
# Epoch: [133/1000], Batch 1, Loss : 106467728.0000
# Current Batch: 2
# Epoch: [133/1000], Batch 2, Loss : 108969888.0000
# Current Batch: 3
# Epoch: [133/1000], Batch 3, Loss : 117465304.0000
# Current Batch: 4
# Epoch: [133/1000], Batch 4, Loss : 100761816.0000
# Current Batch: 5
# Epoch: [133/1000], Batch 5, Loss : 280933024.0000
# Current Batch: 6
# Epoch: [133/1000], Batch 6, Loss : 220222784.0000
# Current Batch: 7
# Epoch: [133/1000], Batch 7, Loss : 76714824.0000
# Current Batch: 8
# Epoch: [133/1000], Batch 8, Loss : 101016296.0000
# Current Batch: 9
# Epoch: [133/1000], Batch 9, Loss : 88030144.0000
# Current Batch: 10
# Epoch: [133/1000], Batch 10, Loss : 247180992.0000
# Current Batch: 11
# Epoch: [133/1000], Batch 11, Loss : 144360880.0000
# Current Batch: 12
# Epoch: [133/1000], Batch 12, Loss : 177844128.0000
# Current Batch: 13
# Epoch: [133/1000], Batch 13, Loss : 117117088.0000
# Current Batch: 14
# Epoch: [133/1000], Batch 14, Loss : 95531952.0000
# Current Batch: 15
# Epoch: [133/1000], Batch 15, Loss : 75323232.0000
# Current Batch: 16
# Epoch: [133/1000], Batch 16, Loss : 89967408.0000
# Current Batch: 17
# Epoch: [133/1000], Batch 17, Loss : 168763904.0000
# Current Batch: 18
# Epoch: [133/1000], Batch 18, Loss : 151174016.0000
# Current Batch: 19
# Epoch: [133/1000], Batch 19, Loss : 150035440.0000
# Current Batch: 20
# Epoch: [133/1000], Batch 20, Loss : 142294064.0000
# Current Batch: 21
# Epoch: [133/1000], Batch 21, Loss : 131009856.0000
# Current Batch: 22
# Epoch: [133/1000], Batch 22, Loss : 88398096.0000
# Current Batch: 23
# Epoch: [133/1000], Batch 23, Loss : 175441200.0000
# Current Batch: 24
# Epoch: [133/1000], Batch 24, Loss : 181302816.0000
# Current Batch: 25
# Epoch: [133/1000], Batch 25, Loss : 191929136.0000
# Current Batch: 26
# Epoch: [133/1000], Batch 26, Loss : 142559184.0000
# Current Batch: 27
# Epoch: [133/1000], Batch 27, Loss : 228354656.0000
# Current Batch: 28
# Epoch: [133/1000], Batch 28, Loss : 101407152.0000
# Current Batch: 29
# Epoch: [133/1000], Batch 29, Loss : 191322112.0000
# Current Batch: 30
# Epoch: [133/1000], Batch 30, Loss : 146351552.0000
# Current Batch: 31
# Epoch: [133/1000], Batch 31, Loss : 147029440.0000
# Current Batch: 32
# Epoch: [133/1000], Batch 32, Loss : 182476688.0000
# Current Batch: 33
# Epoch: [133/1000], Batch 33, Loss : 88881200.0000
# Current Batch: 34
# Epoch: [133/1000], Batch 34, Loss : 166552592.0000
# Current Batch: 1
# Epoch: [134/1000], Batch 1, Loss : 179461904.0000
# Current Batch: 2
# Epoch: [134/1000], Batch 2, Loss : 208256208.0000
# Current Batch: 3
# Epoch: [134/1000], Batch 3, Loss : 147010816.0000
# Current Batch: 4
# Epoch: [134/1000], Batch 4, Loss : 262120048.0000
# Current Batch: 5
# Epoch: [134/1000], Batch 5, Loss : 207971200.0000
# Current Batch: 6
# Epoch: [134/1000], Batch 6, Loss : 147066720.0000
# Current Batch: 7
# Epoch: [134/1000], Batch 7, Loss : 77448464.0000
# Current Batch: 8
# Epoch: [134/1000], Batch 8, Loss : 81312896.0000
# Current Batch: 9
# Epoch: [134/1000], Batch 9, Loss : 70405744.0000
# Current Batch: 10
# Epoch: [134/1000], Batch 10, Loss : 139666928.0000
# Current Batch: 11
# Epoch: [134/1000], Batch 11, Loss : 187127936.0000
# Current Batch: 12
# Epoch: [134/1000], Batch 12, Loss : 156427984.0000
# Current Batch: 13
# Epoch: [134/1000], Batch 13, Loss : 122816784.0000
# Current Batch: 14
# Epoch: [134/1000], Batch 14, Loss : 106602736.0000
# Current Batch: 15
# Epoch: [134/1000], Batch 15, Loss : 134723552.0000
# Current Batch: 16
# Epoch: [134/1000], Batch 16, Loss : 116036928.0000
# Current Batch: 17
# Epoch: [134/1000], Batch 17, Loss : 84335696.0000
# Current Batch: 18
# Epoch: [134/1000], Batch 18, Loss : 123102816.0000
# Current Batch: 19
# Epoch: [134/1000], Batch 19, Loss : 249099088.0000
# Current Batch: 20
# Epoch: [134/1000], Batch 20, Loss : 144109056.0000
# Current Batch: 21
# Epoch: [134/1000], Batch 21, Loss : 121836448.0000
# Current Batch: 22
# Epoch: [134/1000], Batch 22, Loss : 170795728.0000
# Current Batch: 23
# Epoch: [134/1000], Batch 23, Loss : 120565960.0000
# Current Batch: 24
# Epoch: [134/1000], Batch 24, Loss : 153640688.0000
# Current Batch: 25
# Epoch: [134/1000], Batch 25, Loss : 146301008.0000
# Current Batch: 26
# Epoch: [134/1000], Batch 26, Loss : 148393040.0000
# Current Batch: 27
# Epoch: [134/1000], Batch 27, Loss : 88228088.0000
# Current Batch: 28
# Epoch: [134/1000], Batch 28, Loss : 200735904.0000
# Current Batch: 29
# Epoch: [134/1000], Batch 29, Loss : 174475536.0000
# Current Batch: 30
# Epoch: [134/1000], Batch 30, Loss : 91057832.0000
# Current Batch: 31
# Epoch: [134/1000], Batch 31, Loss : 175855088.0000
# Current Batch: 32
# Epoch: [134/1000], Batch 32, Loss : 175347312.0000
# Current Batch: 33
# Epoch: [134/1000], Batch 33, Loss : 74952536.0000
# Current Batch: 34
# Epoch: [134/1000], Batch 34, Loss : 110693688.0000
# Current Batch: 1
# Epoch: [135/1000], Batch 1, Loss : 172165936.0000
# Current Batch: 2
# Epoch: [135/1000], Batch 2, Loss : 155951040.0000
# Current Batch: 3
# Epoch: [135/1000], Batch 3, Loss : 167174496.0000
# Current Batch: 4
# Epoch: [135/1000], Batch 4, Loss : 160855392.0000
# Current Batch: 5
# Epoch: [135/1000], Batch 5, Loss : 61728932.0000
# Current Batch: 6
# Epoch: [135/1000], Batch 6, Loss : 153387760.0000
# Current Batch: 7
# Epoch: [135/1000], Batch 7, Loss : 247324704.0000
# Current Batch: 8
# Epoch: [135/1000], Batch 8, Loss : 102159216.0000
# Current Batch: 9
# Epoch: [135/1000], Batch 9, Loss : 152206192.0000
# Current Batch: 10
# Epoch: [135/1000], Batch 10, Loss : 73155912.0000
# Current Batch: 11
# Epoch: [135/1000], Batch 11, Loss : 134993376.0000
# Current Batch: 12
# Epoch: [135/1000], Batch 12, Loss : 160178816.0000
# Current Batch: 13
# Epoch: [135/1000], Batch 13, Loss : 192453472.0000
# Current Batch: 14
# Epoch: [135/1000], Batch 14, Loss : 138534144.0000
# Current Batch: 15
# Epoch: [135/1000], Batch 15, Loss : 203103776.0000
# Current Batch: 16
# Epoch: [135/1000], Batch 16, Loss : 94036488.0000
# Current Batch: 17
# Epoch: [135/1000], Batch 17, Loss : 172266976.0000
# Current Batch: 18
# Epoch: [135/1000], Batch 18, Loss : 87250968.0000
# Current Batch: 19
# Epoch: [135/1000], Batch 19, Loss : 142398688.0000
# Current Batch: 20
# Epoch: [135/1000], Batch 20, Loss : 132494824.0000
# Current Batch: 21
# Epoch: [135/1000], Batch 21, Loss : 73981184.0000
# Current Batch: 22
# Epoch: [135/1000], Batch 22, Loss : 115346480.0000
# Current Batch: 23
# Epoch: [135/1000], Batch 23, Loss : 181856848.0000
# Current Batch: 24
# Epoch: [135/1000], Batch 24, Loss : 74907360.0000
# Current Batch: 25
# Epoch: [135/1000], Batch 25, Loss : 80834312.0000
# Current Batch: 26
# Epoch: [135/1000], Batch 26, Loss : 214267856.0000
# Current Batch: 27
# Epoch: [135/1000], Batch 27, Loss : 221695328.0000
# Current Batch: 28
# Epoch: [135/1000], Batch 28, Loss : 135258848.0000
# Current Batch: 29
# Epoch: [135/1000], Batch 29, Loss : 114748608.0000
# Current Batch: 30
# Epoch: [135/1000], Batch 30, Loss : 119202320.0000
# Current Batch: 31
# Epoch: [135/1000], Batch 31, Loss : 211390288.0000
# Current Batch: 32
# Epoch: [135/1000], Batch 32, Loss : 214822592.0000
# Current Batch: 33
# Epoch: [135/1000], Batch 33, Loss : 147164672.0000
# Current Batch: 34
# Epoch: [135/1000], Batch 34, Loss : 48503940.0000
# Current Batch: 1
# Epoch: [136/1000], Batch 1, Loss : 110332168.0000
# Current Batch: 2
# Epoch: [136/1000], Batch 2, Loss : 144582576.0000
# Current Batch: 3
# Epoch: [136/1000], Batch 3, Loss : 92403296.0000
# Current Batch: 4
# Epoch: [136/1000], Batch 4, Loss : 161687584.0000
# Current Batch: 5
# Epoch: [136/1000], Batch 5, Loss : 180560192.0000
# Current Batch: 6
# Epoch: [136/1000], Batch 6, Loss : 129160392.0000
# Current Batch: 7
# Epoch: [136/1000], Batch 7, Loss : 130360520.0000
# Current Batch: 8
# Epoch: [136/1000], Batch 8, Loss : 188228128.0000
# Current Batch: 9
# Epoch: [136/1000], Batch 9, Loss : 145295168.0000
# Current Batch: 10
# Epoch: [136/1000], Batch 10, Loss : 174431952.0000
# Current Batch: 11
# Epoch: [136/1000], Batch 11, Loss : 161287120.0000
# Current Batch: 12
# Epoch: [136/1000], Batch 12, Loss : 72742936.0000
# Current Batch: 13
# Epoch: [136/1000], Batch 13, Loss : 142941920.0000
# Current Batch: 14
# Epoch: [136/1000], Batch 14, Loss : 155772992.0000
# Current Batch: 15
# Epoch: [136/1000], Batch 15, Loss : 182325472.0000
# Current Batch: 16
# Epoch: [136/1000], Batch 16, Loss : 93416824.0000
# Current Batch: 17
# Epoch: [136/1000], Batch 17, Loss : 128987248.0000
# Current Batch: 18
# Epoch: [136/1000], Batch 18, Loss : 143990144.0000
# Current Batch: 19
# Epoch: [136/1000], Batch 19, Loss : 124991440.0000
# Current Batch: 20
# Epoch: [136/1000], Batch 20, Loss : 183442304.0000
# Current Batch: 21
# Epoch: [136/1000], Batch 21, Loss : 149883872.0000
# Current Batch: 22
# Epoch: [136/1000], Batch 22, Loss : 129890992.0000
# Current Batch: 23
# Epoch: [136/1000], Batch 23, Loss : 82401616.0000
# Current Batch: 24
# Epoch: [136/1000], Batch 24, Loss : 165662656.0000
# Current Batch: 25
# Epoch: [136/1000], Batch 25, Loss : 175078976.0000
# Current Batch: 26
# Epoch: [136/1000], Batch 26, Loss : 148683904.0000
# Current Batch: 27
# Epoch: [136/1000], Batch 27, Loss : 224831072.0000
# Current Batch: 28
# Epoch: [136/1000], Batch 28, Loss : 101720496.0000
# Current Batch: 29
# Epoch: [136/1000], Batch 29, Loss : 200266064.0000
# Current Batch: 30
# Epoch: [136/1000], Batch 30, Loss : 168101744.0000
# Current Batch: 31
# Epoch: [136/1000], Batch 31, Loss : 111171240.0000
# Current Batch: 32
# Epoch: [136/1000], Batch 32, Loss : 169730880.0000
# Current Batch: 33
# Epoch: [136/1000], Batch 33, Loss : 87198584.0000
# Current Batch: 34
# Epoch: [136/1000], Batch 34, Loss : 163141344.0000
# Current Batch: 1
# Epoch: [137/1000], Batch 1, Loss : 139925312.0000
# Current Batch: 2
# Epoch: [137/1000], Batch 2, Loss : 125739432.0000
# Current Batch: 3
# Epoch: [137/1000], Batch 3, Loss : 189596112.0000
# Current Batch: 4
# Epoch: [137/1000], Batch 4, Loss : 64521596.0000
# Current Batch: 5
# Epoch: [137/1000], Batch 5, Loss : 224788752.0000
# Current Batch: 6
# Epoch: [137/1000], Batch 6, Loss : 143988768.0000
# Current Batch: 7
# Epoch: [137/1000], Batch 7, Loss : 162687088.0000
# Current Batch: 8
# Epoch: [137/1000], Batch 8, Loss : 190495408.0000
# Current Batch: 9
# Epoch: [137/1000], Batch 9, Loss : 138808688.0000
# Current Batch: 10
# Epoch: [137/1000], Batch 10, Loss : 156921728.0000
# Current Batch: 11
# Epoch: [137/1000], Batch 11, Loss : 124892616.0000
# Current Batch: 12
# Epoch: [137/1000], Batch 12, Loss : 102757768.0000
# Current Batch: 13
# Epoch: [137/1000], Batch 13, Loss : 186919296.0000
# Current Batch: 14
# Epoch: [137/1000], Batch 14, Loss : 95679624.0000
# Current Batch: 15
# Epoch: [137/1000], Batch 15, Loss : 153824160.0000
# Current Batch: 16
# Epoch: [137/1000], Batch 16, Loss : 229603792.0000
# Current Batch: 17
# Epoch: [137/1000], Batch 17, Loss : 59577656.0000
# Current Batch: 18
# Epoch: [137/1000], Batch 18, Loss : 202228880.0000
# Current Batch: 19
# Epoch: [137/1000], Batch 19, Loss : 170792048.0000
# Current Batch: 20
# Epoch: [137/1000], Batch 20, Loss : 104274208.0000
# Current Batch: 21
# Epoch: [137/1000], Batch 21, Loss : 143331056.0000
# Current Batch: 22
# Epoch: [137/1000], Batch 22, Loss : 111352816.0000
# Current Batch: 23
# Epoch: [137/1000], Batch 23, Loss : 160566256.0000
# Current Batch: 24
# Epoch: [137/1000], Batch 24, Loss : 167995136.0000
# Current Batch: 25
# Epoch: [137/1000], Batch 25, Loss : 145847792.0000
# Current Batch: 26
# Epoch: [137/1000], Batch 26, Loss : 132282928.0000
# Current Batch: 27
# Epoch: [137/1000], Batch 27, Loss : 249242944.0000
# Current Batch: 28
# Epoch: [137/1000], Batch 28, Loss : 89644600.0000
# Current Batch: 29
# Epoch: [137/1000], Batch 29, Loss : 117855432.0000
# Current Batch: 30
# Epoch: [137/1000], Batch 30, Loss : 175685440.0000
# Current Batch: 31
# Epoch: [137/1000], Batch 31, Loss : 121512312.0000
# Current Batch: 32
# Epoch: [137/1000], Batch 32, Loss : 84491592.0000
# Current Batch: 33
# Epoch: [137/1000], Batch 33, Loss : 115333408.0000
# Current Batch: 34
# Epoch: [137/1000], Batch 34, Loss : 100437208.0000
# Current Batch: 1
# Epoch: [138/1000], Batch 1, Loss : 195818864.0000
# Current Batch: 2
# Epoch: [138/1000], Batch 2, Loss : 206084000.0000
# Current Batch: 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 17
#      15 predictions = model(batch_X)
#      16 loss = criterion(predictions, batch_y)
# ---> 17 loss.backward() #  compute gradients
#      19 optimizer.step() # update weights using gradients computed
#      20 print(f"Epoch: [{epoch+1}/{epochs}], Batch {batch_idx + 1}, Loss : {loss.item():.4f}")
#
# File ~/anaconda3/envs/pytorch_gpu12_8/lib/python3.11/site-packages/torch/_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)    623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# File ~/anaconda3/envs/pytorch_gpu12_8/lib/python3.11/site-packages/torch/autograd/__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File ~/anaconda3/envs/pytorch_gpu12_8/lib/python3.11/site-packages/torch/autograd/graph.py:841, in _engine_run_backward(t_outputs, *args, **kwargs)
#     839     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840 try:
# --> 841     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842         t_outputs, *args, **kwargs
#     843     )  # Calls into the C++ engine to run the backward pass
#     844 finally:
#     845     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# What about the num_workers ? 
# it is possible to change it values e.e 4, allowing parallel processing 
# 4 threads work simultaneusly to load data
# 4 separate processes to load data in parallel. Already in load state, already available data !
# Reduced time to load time 


# With a smart DataLoading technique: 
# - Stabilize training, more frequent gradient update 
# - Reduce memory usage 
# - Generalize better by shuffling, which prevent overfitting 

# - MIN BATCH TRAINING TECHNIQUE, introduce randomness by shuffling
